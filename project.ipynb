# %%
import numpy as np
import datetime
from PIL import Image
import pytesseract as tess
tess.pytesseract.tesseract_cmd =r'C:\Users\reeta\Anaconda3\pkgs\Tesseract-OCR\tesseract.exe'
#-- we can strore data in the class so that we can manipulate data easily ------

def imgrec():         #------ this function is used to convert image of number plate to text using ocr
    
    num_plate='number.jpg'
    
    img=Image.open(num_plate)
    
    text=tess.image_to_string(img)
    
    return(text)

#----------------------------------------------------------------------------
#----------- TEST FUNCTION -- WILL BE USED IN FUTURE IMPLICATION
#------------------------------------------------------------------------------

def timecounter():

    for i in range(3):

        vab=intime[i]+vab

    print(vab)  

#----------------------------------------------------------------------------

#----- THIS FUNCTION WILL GIVE US THE NUMBER OF VEHICLES STILL IN SYSTEM-----

#----------------------------------------------------------------------------

 

def countvehin():

   

    count=0

    for i in range(len(veh)):

        if veh[i][2]=='NULL':

            count+=1

    print(' the number of vehicles still in the university = ' , count)      #-- here we can also use a list of vehicles in the system. such functionality will be made available in futute updates

#-----------------------------------------------------------------------------

#----- MENU TO PROVIDE OPTION TO USER TO SELECT ENTRY OR EXIT OF VEHICLE -----

#-----------------------------------------------------------------------------

 

def menu():

   

    print('\n\t\t\t\tVEHICLE ENTRY SYSTEM')

    print('\n\n')

    print('\t1). vehicle entry ')

    print('\t2). vehicle exit  ')

    print('\t3). number of vehicles in university ')

    print('\t4). the list of all vehicles that were in the university ')

    choice=input('\tEnter your choice \n')

    return(choice)

 

#------------------------------------------------------------------------------  

#----- THIS FUNCTION WILL HANDLE ALL THE QUERY OF VEHICLE ENTRY----------------

#------------------------------------------------------------------------------

 

def intim():

   

    intime=datetime.datetime.now().strftime("%I:%M%p")

    outime='NULL'

    vehtemp.append(text)

    vehtemp.append(intime)

    vehtemp.append(outime)

    veh.append(vehtemp)

 

   

#------------------------------------------------------------------------------

#------ THIS FUNCTION WILL HANDLE THE EXIT OF THE VEHICLE----------------------

#------------------------------------------------------------------------------

def outim(text):

   

    vehout=text

    flag=0
    
    token=0

    for i in range(len(veh)):

        if vehout==veh[i][0]:

            flag=1

            pos=i

            outime =datetime.datetime.now().strftime("%I:%M%p")

            veh[i][2]=outime

            veh.pop(i) #-----------------------------------------ERROR ----------------------------------

    if flag==0 :
        while token != 1:
            print(' vehicle not found in the system please try manual approch ')
            token+=1
            again=int(input(' please enter the vehicle number manualy'))
            outim(again)
            return(0)
       

       

    else:

        print(' vehicle found in the system ')

        print(' {0} exit the university at {1} '.format(text , outime))

#------------------------------------------------------------------------------

#---------- BEYOUND THIS POINT , OUR MAIN PROGRAM WILL START EXECUTION --------

#------------------------------------------------------------------------------

 

ans='y'

vehtemp=[] #--- this list is used to store vehicle data

veh=[]  #--- this list is used to store entry time , exit time and vehicle number of various vehicles in a 2d list for each vehicles

token=0  #--- this is a token to use manual approch in the vehicle exit senario 

while ans=='Y' or ans=='y' :

    choi=menu()   #--- a is a variable which will only store the choice selected by the user  

    if choi=='1':

        vehtemp=[]  #--- this list is used to store entry time , exit time and vehicle number of various vehicles in a 2d list for each vehicles

        text=imgrec()

        intime=intim()

       

    elif choi=='2':

        text=imgrec()
        outime=outim(text)

    elif choi=='3':

        countvehin()  #---------------------------------------- THIS FUNCTION IS OUR FUTURE IMPLEMENTATION---

    elif choi=='4':

        print(veh)

    else:

        print(' You have entered wrong option ')

    ans=input(' Do you wish to continue (y/n) ?? ')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-1f629c657aeb> in <module>
#       2 import datetime
#       3 from PIL import Image
# ----> 4 import pytesseract as tess
#       5 tess.pytesseract.tesseract_cmd =r'C:\Users\reeta\Anaconda3\pkgs\Tesseract-OCR\tesseract.exe'
#       6 #-- we can strore data in the class so that we can manipulate data easily ------
#
# ModuleNotFoundError: No module named 'pytesseract'
